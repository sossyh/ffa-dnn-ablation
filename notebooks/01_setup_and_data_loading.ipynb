# %% [markdown]
# # 01 - Setup and Data Loading
#
# This notebook clones the project repo, sets up the dataset download link, downloads the Algonauts 2021 Mini-Track dataset, and loads fMRI ROI data for a subject to confirm everything works.
#
# **Run cells in order.**

# %% [markdown]
# ## Step 1: Clone the repo
#
# This pulls down the whole project (including `src/`) so imports work normally.

# %%
# !git clone https://github.com/sossyh/ffa-dnn-ablation.git
# %cd ffa-dnn-ablation
# Out:
# Cloning into 'ffa-dnn-ablation'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 46 (delta 19), reused 31 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 14.95 KiB | 4.98 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# /content/ffa-dnn-ablation/ffa-dnn-ablation

# %% [markdown]
# ## Step 2: Set the dropbox link as an environment variable
#
# Since `.env` is gitignored (it holds secrets/links, so it never gets committed), we
# set the variable directly here for now. If you'd rather use Colab's built-in Secrets
# manager instead (safer, recommended long-term), see the commented-out alternative below.

# %%
import os

from google.colab import userdata
os.environ["DROPBOX_DATASET_LINK"] = userdata.get("DROPBOX_DATASET_LINK")

# %% [markdown]
# ## Step 3: Install any missing dependencies

# %%
# !pip install nilearn python-dotenv --quiet

# %% [markdown]
# ## Step 4: Import the data loading functions from `src/`

# %%
import sys
sys.path.append(".")

from src.data_loading import download_algonauts_data, load_all_rois

# %% [markdown]
# ## Step 5: Download the dataset
#
# This downloads and extracts the Algonauts 2021 data into `data/raw/`.

# %%
download_algonauts_data(data_dir="data/raw")
# Out:
# Downloading Algonauts data...
# Download complete.

# %% [markdown]
# ## Step 6: Inspect the extracted folder structure
#
# Run this before trying to load ROI data, since the exact subfolder name inside
# the extracted zip needs to be confirmed before we hardcode a path.

# %%
import os

for root, dirs, files in os.walk("data/raw/participants_data_v2021"):
    print(root, dirs, files[:5])
# Out:
# data/raw/participants_data_v2021 ['mini_track', 'full_track'] []
# data/raw/participants_data_v2021/mini_track ['sub10', 'sub01', 'sub05', 'sub04', 'sub02', 'sub08', 'sub09', 'sub07', 'sub06', 'sub03'] []
# data/raw/participants_data_v2021/mini_track/sub10 [] ['EBA.pkl', 'STS.pkl', 'PPA.pkl', 'V1.pkl', 'V2.pkl']
# data/raw/participants_data_v2021/mini_track/sub01 [] ['EBA.pkl', 'STS.pkl', 'PPA.pkl', 'V1.pkl', 'V2.pkl']
# data/raw/participants_data_v2021/mini_track/sub05 [] ['EBA.pkl', 'STS.pkl', 'PPA.pkl', 'V1.pkl', 'V2.pkl']
# data/raw/participants_data_v2021/mini_track/sub04 [] ['EBA.pkl', 'STS.pkl', 'PPA.pkl', 'V1.pkl', 'V2.pkl']
# data/raw/participants_data_v2021/mini_track/sub02 [] ['EBA.pkl', 'STS.pkl', 'PPA.pkl', 'V1.pkl', 'V2.pkl']
# data/raw/participants_data_v2021/mini_track/sub08 [] ['EBA.pkl', 'STS.pkl', 'PPA.pkl', 'V1.pkl', 'V2.pkl']
# data/raw/participants_data_v2021/mini_track/sub09 [] ['EBA.pkl', 'STS.pkl', 'PPA.pkl', 'V1.pkl', 'V2.pkl']
# data/raw/participants_data_v2021/mini_track/sub07 [] ['EBA.pkl', 'STS.pkl', 'PPA.pkl', 'V1.pkl', 'V2.pkl']
# data/raw/participants_data_v2021/mini_track/sub06 [] ['EBA.pkl', 'STS.pkl', 'PPA.pkl', 'V1.pkl', 'V2.pkl']
# data/raw/participants_data_v2021/mini_track/sub03 [] ['EBA.pkl', 'STS.pkl', 'PPA.pkl', 'V1.pkl', 'V2.pkl']
# data/raw/participants_data_v2021/full_track ['sub10', 'sub01', 'sub05', 'sub04', 'sub02', 'sub08', 'sub09', 'sub07', 'sub06', 'sub03'] []
# data/raw/participants_data_v2021/full_track/sub10 [] ['WB.pkl']
# data/raw/participants_data_v2021/full_track/sub01 [] ['WB.pkl']
# data/raw/participants_data_v2021/full_track/sub05 [] ['WB.pkl']
# data/raw/participants_data_v2021/full_track/sub04 [] ['WB.pkl']
# data/raw/participants_data_v2021/full_track/sub02 [] ['WB.pkl']
# data/raw/participants_data_v2021/full_track/sub08 [] ['WB.pkl']
# data/raw/participants_data_v2021/full_track/sub09 [] ['WB.pkl']
# data/raw/participants_data_v2021/full_track/sub07 [] ['WB.pkl']
# data/raw/participants_data_v2021/full_track/sub06 [] ['WB.pkl']
# data/raw/participants_data_v2021/full_track/sub03 [] ['WB.pkl']

# %% [markdown]
# ## Step 7: Load ROI data for one subject
#
# **Update `fmri_dir` below based on what Step 6 printed**, if the folder name
# differs from the guess here.

# %%
fmri_dir = "data/raw/participants_data_v2021/mini_track"
subject = "sub01"

roi_data = load_all_rois(fmri_dir, subject)

for roi_name, data in roi_data.items():
    print(f"{roi_name}: {data.shape}")
# Out:
# V1: (1000, 232)
# V2: (1000, 231)
# V3: (1000, 261)
# V4: (1000, 107)
# LOC: (1000, 1843)
# EBA: (1000, 351)
# FFA: (1000, 68)
# STS: (1000, 341)
# PPA: (1000, 425)

# %% [markdown]
# If this printed shapes like `FFA: (1000, 45)` for every ROI, the data loaded
# correctly and you're ready to move on to `02_baseline_encoding_model.ipynb`.
